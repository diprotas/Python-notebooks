# %% [raw]
# Прочитав эту главу, читатель сможет
# • Понять процедурную, модульную и объектно-ориентированную парадигму.
# • Понять концепцию класса
# • Создайте класс
# • Понять элементы объектно-ориентированного программирования.

# %% [markdown]
# 9.1. ВВЕДЕНИЕ

# %% [raw]
# В предыдущих главах обсуждались управляющие структуры Python.
# В первом разделе обсуждались циклы, условные операторы и т. Д. Однако эти конструкции также были неотъемлемой частью C, который является процедурным языком. В процедурном программировании используются процедуры. Каждая процедура - это набор инструкций, каждая из которых указывает компьютеру, что нужно сделать. Python также поддерживает объектно-ориентированное программирование (ООП). Эта глава знакомит с принципами ООП и объясняет необходимость и важность классов и объектов. В этой главе также обсуждается разница между ООП и процедурным программированием, чтобы понять, почему ООП необходимо.
# Здесь можно указать, что темы, обсуждаемые в этой главе, будут подробно обсуждаться в следующих главах. Некоторые из читателей, не знакомые с C ++ (или, если на то пошло, C# или Java), могут найти обсуждение абстрактным, но все станет ясно по мере продвижения.
# Как указывалось ранее, в процедурном программировании каждый оператор сообщает программе, что делать. Например, следующий код запрашивает у пользователя ввод, вычисляет квадратный корень и отображает результат.

# %%
import math
a = float(input("Enter a number\t:"))
b = math.sqrt(a)
b
# Out:
# Enter a number	:23
# 4.795831523312719

# %% [raw]
# Нет парадигмы
# • Подходит для небольших программ
# • Каждая инструкция указывает компьютеру, что делать.
#
# Модульное программирование
# • Программа разделена на функции
# • Соответствующие функции объединены вместе
#
# Объектно-ориентированное программирование
# • Классы занимают центральное место в программе.
# • Экземпляры класса (Объекты) общаются друг с другом

# %% [raw]
# Процедурная стратегия хороша, если программа очень маленькая. Часто пошаговые инструкции компьютеру, что делать, срабатывают, если задача, которую нужно выполнить, не очень сложна. В таких случаях иная парадигма не нужна.
#
# В случае умеренно большой программы разделение на функции облегчает задачу. Разделение более крупной программы на функции делает программу управляемой и помогает добиться повторного использования кода. Функции обычно выполняют четко определенную задачу и становятся полезными всякий раз, когда эта конкретная задача должна быть выполнена. Читателю рекомендуется просмотреть главу о функциях, чтобы понять преимущества функций. Объединение функций на некоторой основе приводит к тому, что обычно называют модулями. Парадигма программирования с использованием модулей называется модульным программированием. Проблема этой парадигмы состоит в том, что случайное объединение несвязанных функций, далеких от реальных ситуаций, в какой-то момент становится источником проблем. Более того, такой подход не ограничивает доступ к данным в каком-либо модуле и может поставить под угрозу неприкосновенность данных.
# Следует отметить, что данные не должны быть доступны для всех модулей.
# Доступностью данных необходимо управлять с особой тщательностью, иначе модуль, который не должен реагировать на данные в соответствии с логикой программы, может изменить данные.
# Чтобы понять серьезность проблемы, возьмем пример C. В C переменная может быть глобальной или локальной. Если она глобальная, то её может изменить любой модуль. Если она локальная, то другие модули не могут получить к нему доступ. Так что между ними нет ничего. То есть мы не можем создать переменную, к которой можно будет получить доступ только назначенными методами, а не данными.
# Решение вышеуказанной проблемы состоит в том, чтобы смоделировать программное обеспечение таким образом, чтобы проект концептуально был максимально приближен к реальному миру. Это моделирование ситуаций реального мира требует создания сущностей, обладающих как атрибутами, так и поведением. Объединение данных и функций, которые манипулируют данными, могут быть полезны при создании вышеупомянутых сущностей. Эти объекты в дальнейшем будут называться классами. Экземпляры классов являются объектами, а парадигма называется объектно-ориентированной парадигмой. Различные парадигмы программирования и их недостатки суммированы на рисунке 9.1.

# %% [markdown]
# 9.2. СОЗДАНИЕ НОВЫХ ТИПОВ

# %% [raw]
# Хотя типы явно не объявляются в Python, типы были важны в других языках (ну, в большинстве из них). Например, когда кто-то говорит, что «число» имеет целочисленный тип, он указывает не только тип информации, но также его максимальное и минимальное значение. Предположим, что целое число занимает два байта; максимальное значение «число» будет 32767, а минимальное значение - –32768. Более того, указание, что «число» имеет целочисленный тип, также указывает операции, которые могут быть выполнены с числом. Целое число - это предопределенный тип. Большинство языков также позволяют пользователю создавать собственные типы и, следовательно, расширять возможности встроенных типов. Это важно, поскольку возможность создавать новые типы данных поможет нам создавать программы, близкие к реальному миру. Например, если нужно разработать систему управления запасами, то такой тип, называемый «предметом», упростит задачу. Этот элемент может иметь переменные предопределенного типа, например целые числа и строки.
#
# Новый тип можно создать, объявив класс. Класс состоит из множества компонентов, наиболее важными из которых являются атрибуты и функции.
#
# Это объединение функций и данных составляет основу ООП. Функции, как мы увидим позже, обычно управляют членами данных класса. Прежде чем продолжить, давайте сделаем обзор атрибутов и функций.

# %% [markdown]
# 9.3. АТРИБУТЫ И ФУНКЦИИ

# %% [raw]
# Можно воспринимать класс как прототип, а объект как экземпляр класса. Например, «фильм» - это класс, а конкретные фильмы такие, как «Гостья из будущего», «Семнадцать мгновений весны» и «Весна» - это объекты. У класса есть атрибуты и поведение. Атрибуты обычно хранят данные, а поведение реализуется с помощью функций. Класс можно изобразить с помощью диаграммы классов. Диаграмма классов обычно состоит из трех частей; первая часть содержит имя, вторая часть содержит атрибуты, а третья часть показывает функции класса. Основы атрибутов и поведения обсуждаются в следующем разделе. На рисунке 9.2 диаграмма классов (фильм) имеет только имя.

# %% [markdown]
# 9.3.1. Атрибуты

# %% [raw]
# Атрибуты здесь отображают характеристики объекта, который нас интересует. Например, при создании веб-сайта с подробной информацией о фильмах потребуется класс «фильм». Скажем, после подробных обсуждений было решено, что этот класс будет иметь такие атрибуты, как имя, год, жанр, режиссер, продюсер, актеры, музыкальный руководитель и сценарист.
# Обратите внимание, что для указанной цели необходимы только указанные выше данные. Хранение ненужных деталей не только затруднит управление данными, но также нарушит один из основных принципов - включение только деталей, относящихся к рассматриваемой проблеме. Эти атрибуты обычно показаны во втором разделе диаграммы классов. На рисунке 9.3 показаны атрибуты класса «фильм».
#
#            --------------------|
#            |   Name: Movie     |
#            |-------------------|
#            |   Attributes:     |
#            |   name,           |
#            |   year,           |
#            |   genre,          |
#    Class   |   director,       |
#            |   producer,       |
#            |   actors,         |
#            |   music_director, |
#            |   story_writer	   |
# 	       |-------------------|
#
#   Рисунок 9.3 Имя и атрибуты класса movie

# %% [markdown]
# 9.3.2. Функции

# %% [raw]
# Следующим шагом будет включение функций в вышеуказанный класс. В нашем примере есть две функции - getdata() и putdata(). Функция getdata() запрашивает значения переменных у пользователя, а функция putdata() - отображает данные. Функции реализуют поведение класса. Функции, как указывалось ранее, решают конкретную задачу. В классе может быть любое количество функций, каждая из которых выполняет определенную задачу. На самом деле у нас есть специальные функции для инициализации членов данных класса. В дальнейшем функции класса будут называться функциями-членами. Функции (или поведение) показаны в третьем разделе диаграммы классов. На рисунке 9.4 функции класса «фильм» (getdata () и putdata ()) показаны в третьем поле.
#
#
#            --------------------|
#            |   Name: Movie     |
#            |-------------------|
#            |   Атрибуты:       |
#            |   name,           |
#            |   year,           |
#            |   genre,          |
#    Class   |   director,       |
#            |   producer,       |
#            |   actors,         |
#            |   music_director, |
#            |   story_writer	   |
# 	       |-------------------|
#            |   Функции:        |
#            |    getdata()      |
#            |    putdata()      |
#            |-------------------|
#
#   Рисунок 9.3 Имя, атрибуты и функции класса movie
#
# В следующем примере показан класс с именем movies. Класс имеет следующие члены данных:
# Имя
# Год
# Жанр
# Директор
# Режиссер
# Актеры
# Музыкальный руководитель
# Сценарист
#
# В классе есть две функции - getdata (), которая просит пользователя ввести значения элементов данных, и putdata (), которая отображает значения переменных. Для вызова функций getdata () и putdata () создается экземпляр класса  ('m'). Как мы увидим позже, функции вызываются с помощью dot-оператора (точки). Детали, касающиеся синтаксиса, будут объяснены в следующей главе.
# Следующий код реализует вышеуказанный класс. Хотя этика синтаксиса… пока не обсуждалась, код был дан, чтобы дать представление о том, как все работает на самом деле.

# %%
class movie:
    def getdata(self):
        self.name = input('Введите название фильма \t:')
        self.year = int(input('Введите год \t:'))
        self.genre = input('Введите жанр фильма \t:')
        self.director = input('Введите режисера фильма \t:')
        self.producer = input('Введите продюсера фильма \t:')
        
        List_actors = []
        item = input('Введите ФИО актёра \t:')
        List_actors.append(item)
        choice = input('Нажмите \'y\' для дальнейшего ввода или  \'n\' для выхода')
        while choice == 'y':
            item = input('Введите ФИО актёра \t:')
            List_actors.append(item)
            choice = input('Нажмите \'y\' для дальнейшего ввода или  \'n\' для выхода')
        
        self.actors = List_actors
        self.music_director = input('Введите ФИО композитора \t:')
    
    def putdata(self):
        print('Фильм \t:', self.name)
        print('Год \t',self.year)
        print('Жанр \t:',self.genre)
        print('Режиссер \t:',self.director)
        print('Продьюсер \t:', self.producer)
        print('Композитор \t:', self.music_director)
        print('Актёры \t:',self.actors)
# ===========конец=описания=класа=======================

m = movie()
m.getdata()
m.putdata()
# Out:
# Введите имя 	:Kapoor
# Введите год 	:2016
# Введите жанр фильма 	:Drama
# Введите режисера фильма 	:ABC
# Введите продюсера фильма 	:СВА
# Введите ФИО актёра 	:Siddarth
# Нажмите 'y' для дальнейшего ввода или  'n' для выходаy
# Введите ФИО актёра 	:Fawad
# Нажмите 'y' для дальнейшего ввода или  'n' для выходаn
# Введите ФИО композитора 	:Marooh
# NameXt: Kapoor
# YearXt 2016
# GenreXt: Drama
# DirectorXt: ABC
# ProducerXt: СВА
# Music_director	: Marooh
# ActorsXt: ['Siddarth', 'Fawad']

# %% [raw]
# В объектно-ориентированных языках специальная функция инициализирует значение элементов данных. Эта функция обычно имеет то же имя, что и класс. Функция называется конструктором.
# В классе можно создать конструктор по умолчанию, который не принимает никаких параметров. С другой стороны, параметризованный конструктор принимает аргументы и инициализирует элементы данных, используя эти аргументы. Реализация конструкторов и их использование будут рассмотрены в следующей главе.
# Когда время жизни объекта заканчивается, вызывается деструктор. Деструктор можно вызвать с помощью del в Python. Концепция будет объяснена в следующей главе этой книги.
#
# Совет
#
# Конструктор действует при создании объекта, а деструктор вызывается, когда время жизни объекта заканчивается.

# %% [markdown]
# 9.4. ЭЛЕМЕНТЫ ООП

# %% [raw]
# Следующее обсуждение кратко описывает принципы объектно-ориентированного программирования. В этом разделе обсуждаются концепции инкапсуляции, сокрытия данных и полиморфизма.
#
# 9.4.2 Класс
#
# Класс - это реальный или виртуальный объект, имеющий отношение к рассматриваемой проблеме и имеющий четкие физические границы. Класс может быть реальной сущностью. Например, когда кто-то разрабатывает программное обеспечение для компании по мойке автомобилей, тогда «Автомобиль» занимает центральное место в программном обеспечении, и поэтому будет класс под названием «Автомобиль». Класс также может быть виртуальным объектом. Другой пример: при разработке системы управления учениками создается класс «ученик», который представляет собой виртуальную сущность. В обоих примерах сущность была создана, так как она важна для решаемой проблемы.
# Пример «студенческого» класса можно продолжить. У класса будут атрибуты, которые необходимы программе. Выбор атрибутов определит физические границы класса. Дело в том, что нам не понадобятся лишние детали, такие как количество автомобилей у студента или куда он ездил вчера вечером в учебном заведении, для которого мы создаем систему управления студентами, поэтому нет смысла хранить эти детали.
# Примеры некоторых классов, которые являются центральными для заявленного программного обеспечения, следующие (Таблица 9.1).
#
# Таблица 9.1 Примеры основных классов для различных IT-систем
#
# IT-СИСТЕМА                       ОСНОВНОЙ КЛАСС ДЛЯ SOFTWARE
# Student Management System        Student  (Студент)
# Employee Management System       Employee (Сотрудник)
# Inventory Control                Item  (Предмет)
# Library Management               Book  (Книга)
# Movie Review                     Movie  (Фильм)
# Airline Management               Flight  (Авиарейс)
# Examination                      Test    (Тест)

# %% [markdown]
# 9.4.2 ОБЪЕКТ

# %% [raw]
# Рассмотрим IT-систему управления учениками, в которой хранятся данные о каждом ученике школы. Обратите внимание, что при вводе данных оператор будет иметь дело с отдельным студентом, а не с идеей студента. Идея (модель) ученика - это класс, тогда как каждый ученик - это экземпляр класса или объект.
# Объект - это экземпляр класса. Объекты взаимодействуют друг с другом и выполняют свою работу. Как правило, в классе может быть любое количество объектов. Можно даже сформировать массив объектов. В примере с «фильмом» в качестве объекта использовалась буква «м». По сути, мы создаем объект и вызываем методы класса (те, которые могут быть вызваны).
# В объектно-ориентированной парадигме программа вращается вокруг объекта, и поэтому тип программирования называется объектно-ориентированной программой.
# Вызов метода объекта эквивалентен отправке сообщения объекту.
#
# 9.4.3. Инкапсуляция
# Класс - это сущность, которая имеет как данные, так и функции. Объединение данных и функций, которые работают с этими данными, называется инкапсуляцией. Инкапсуляция - один из основных принципов объектно-ориентированной парадигмы. Инкапсуляция не только упрощает работу с объектами, но и улучшает управляемость программного обеспечения.
# Более того, функции класса можно использовать по-разному. Доступностью элементов данных и функций-членов также можно управлять с помощью спецификаторов доступа, как описано в следующем подразделе.
#
# 9.4.4. Скрытие данных
# Скрытие данных - еще один важный принцип объектно-ориентированного программирования.
# Как указано в приведенном выше обсуждении, доступностью данных можно управлять в классе. В случае процедурного программирования данные доступны для всех во всей программе. Это называется глобальными данными. Данные, частные для класса, могут быть доступны только членам класса. Существуют и другие спецификаторы доступа, которые объясняются в следующих разделах. Например, в C++ данные в классе обычно остаются закрытыми. То есть только функции-члены класса могут получить доступ к данным. Это гарантирует, что данные не будут случайно изменены. С другой стороны, функции являются общедоступными в C++. Доступ к публичным функциям можно получить в любом месте программы (рис. 9.5). В C++, Java, C# и прочем есть еще один защищенный спецификатор доступа. Если необходимо получить доступ к члену в классе и производном классе, то используется защищенный спецификатор. В C# и Java также есть некоторые другие спецификаторы, например internal.
#      Public - доступен из любого места
#      Private - доступен только внутри класса
#
# Обсудив доступ к данным, необходимо пояснить, что решение о том, что является частным, а что общедоступным, остается на усмотрение группы проектирования и разработки проекта. Не существует жестких правил относительно того, что должно быть частным, а что - публичным. Дизайнеры должны выбрать доступность элемента в зависимости от своих потребностей.
# Эта защита данных связана не с безопасностью данных, а со случайным изменением. Это необходимо для того, чтобы данные можно было изменять только с помощью функций, которые имеют право изменять данные.
#
# 9.4.5. Наследование
# Классы сделаны так, чтобы из них можно было создавать подклассы. Это искусство создания из класса подкласса - это наследование. Например, из класса фильм можно создать различные подклассы, такие как art_movie, Commercial_movie и прочее. Аналогичным образом, класс ученика может породить  подклассы «обычный ученик» и «part_time_student». В обоих примерах подкласс имеет много общего с базовым классом (класс, из которого был получен подкласс). Кроме того, каждый подкласс может иметь функции и данные, которые принадлежат только подклассу. Например, класс ученика может иметь атрибуты, а именно имя, дату_ рождения, адрес и т. Д. Обычный ученик подкласса будет использовать все указанные выше элементы данных, а также может с ним связаны такие атрибуты, как посещаемость. Класс, из которого будут созданы подклассы, называется базовым классом, а подклассы будут называться производными классами.
# Например, на рисунке 9.6 movie является базовым классом, а Commercial_movie и art_movie - подклассами.
#
# 9.4.6. Полиморфизм
#
# Поли означает множество, а морфизм - это формы, поэтому полиморфизм означает множество форм. Полиморфизм можно реализовать разными способами. Один из простейших примеров полиморфизма - перегрузка операторов. Перегрузка оператора означает использование одного и того же оператора более чем одним способом. Например, «+» используется между целыми числами, которые нужно добавить, со строками для конкатенации и даже может использоваться в пользовательских типах данных, как описано в главе 12 этой книги.
# Точно так же перегрузка функции означает наличие более одной функции с одним и тем же именем в классе с разными аргументами. Различные формы полиморфизма описаны в главах 10 и 11 этой книги.
#
# 9.4.7. Возможность повторного использования
# Процедурное программирование практически не допускало повторного использования. Модульное программирование допускало повторное использование, но только до определенной степени. Функции могут использоваться «как есть» в модульном программировании. В объектно-ориентированном программировании концепция повторного использования может использоваться в полной мере. Концепция наследования, представленная выше и объясненная в главе 10 этой книги, помогает программисту повторно использовать код в соответствии с их требованиями. Фактически, возможность повторного использования - одно из достоинств объектно-ориентированной парадигмы.
# Однако здесь есть одна загвоздка. В последнее время некоторые исследователи подвергли сомнению способность ООП к повторному использованию.
#
# ЗАКЛЮЧЕНИЕ
#
# При разработке программного обеспечения нужно помнить о сущностях, с которыми оно будет работать. Мельчайшие детали могут быть решены на более позднем этапе. Фактически, популярная литература не рассматривает детали операции как предмет озабоченности объектно-ориентированного программирования. Таким образом, сокрытие ненужных деталей - важная часть объектно-ориентированного программирования.
# Например, при разработке веб-сайта для фильмов центральным элементом проблемы является «Фильм». Итак, мы начинаем с пустого класса под названием «фильм».
# Затем разработчик должен выбрать атрибуты, необходимые для реализации функций. Атрибуты составляют элементы данных указанного класса. Затем обсуждается поведение сущности. Функция-член определяет поведение класса. Затем разрабатываются функции. В игру вступают такие вещи, как наследование и полиморфизм, обсуждаемые далее в этом разделе. И наконец система создана.
# Этот путь формирования класса изображен на следующем рисунке (рис. 9.7).
# Программирование - это искусство. Хороший программист должен хорошо разбираться в синтаксисе языка, структурах данных и концепциях анализа алгоритмов. В дополнение к вышесказанному программисту необходимо решить, какую парадигму программирования он собирается использовать. В этой главе кратко представлены различные парадигмы программирования, а также их преимущества и недостатки. В этой главе вводится понятие объектно-ориентированного программирования. В этой главе обсуждались определения класса, объекта и т. Д. В этой главе также представлены возможности ООП.
# Концепции, представленные в этой главе, лягут в основу оставшейся части главы этого раздела. Как уже говорилось, некоторые концепции могут показаться абстрактными на этом этапе, но в следующих главах мы вернемся к концепциям и продемонстрируем реализацию идей, рассмотренных в этой главе. Чтобы иметь возможность создать программу, использующую ООП, нужно отказаться от процедурного мышления и начать думать о программе, которая сосредоточена на объектах реального мира, имеющих атрибуты и поведение.
# Можно также сказать, что проектированию объектно-ориентированной программы обычно предшествует разработка диаграмм классов, диаграмм последовательностей и т. Д. Они являются частью Unified Modeling Language. Концепция диаграмм классов была представлена ​​в этой главе, а UML был представлен в ссылках в конце главы. Читателю рекомендуется просмотреть ссылки в конце главы, прежде чем продолжить.
#
# ГЛОССАРИЙ
# Класс: класс - это реальная или виртуальная сущность, имеющая отношение к рассматриваемой проблеме и имеющая четкие физические границы.
# Объект: объект - это экземпляр класса.
# Инкапсуляция: объединение данных и функций, которые работают с данными, называется инкапсуляцией.
# Наследование. Искусство разделения класса на подклассы - это наследование.
# Перегрузка оператора: перегрузка оператора, как правило, означает использование одного и того же оператора более чем одним способом.
# Перегрузка функций: это означает наличие более одной функции с одним и тем же именем в классе с разными аргументами.
